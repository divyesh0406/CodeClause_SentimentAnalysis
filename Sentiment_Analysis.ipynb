# %%
import torch
import pandas as pd
from tqdm.notebook import tqdm

from transformers import BertTokenizer
from torch.utils.data import TensorDataset

from transformers import BertForSequenceClassification

df_train = pd.read_csv("C:/Users/divye/Downloads/Sentiment-Analysis/train.csv", sep =',')

print(df_train.head())
# Out:
#                                                Input Sentiment
# 0          I can't understand the method of teaching  Negative
# 1  The instructor was interested in the students ...  Positive
# 2  The instructor don't use any examples for expl...  Negative
# 3          Teaching is good but always late to class   Neutral
# 4                               Explaination is poor  Negative

# %%
df_train['Sentiment'].value_counts()
# Out:
# Positive    576
# Negative    493
# Neutral     233
# Name: Sentiment, dtype: int64

# %%
df_train['Sentiment'].isnull().values.any() #checking for anu null values
# Out:
# False

# %%
from tensorflow.keras.utils import to_categorical

# %%
encoded_dict = {'Neutral':0,'Positive':1, 'Negative':2 }
df_train['Sentiment'] = df_train.Sentiment.map(encoded_dict)

# %%
df_train
# Out:
#                                                   Input  Sentiment
# 0             I can't understand the method of teaching          2
# 1     The instructor was interested in the students ...          1
# 2     The instructor don't use any examples for expl...          2
# 3             Teaching is good but always late to class          0
# 4                                  Explaination is poor          2
# ...                                                 ...        ...
# 1297                   All is there except indoor games          0
# 1298              All is well except fitness equipments          0
# 1299         Everything is fine except ground condition          0
# 1300  Ground is in best condition but no gaming equi...          0
# 1301                                   No proper timing          0
#
# [1302 rows x 2 columns]

# %%
y_train = to_categorical(df_train.Sentiment)

# %%
y_train
# Out:
# array([[0., 0., 1.],
#        [0., 1., 0.],
#        [0., 0., 1.],
#        ...,
#        [1., 0., 0.],
#        [1., 0., 0.],
#        [1., 0., 0.]], dtype=float32)

# %%
from transformers import AutoTokenizer,TFBertModel
tokenizer = AutoTokenizer.from_pretrained('bert-base-cased')
bert = TFBertModel.from_pretrained('bert-base-cased')
# Out:
# Some layers from the model checkpoint at bert-base-cased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-cased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.

# %%
x_train = tokenizer(
    text=df_train.Input.tolist(),
    add_special_tokens=True,
    max_length=70,
    truncation=True,
    padding=True, 
    return_tensors='tf',
    return_token_type_ids = False,
    return_attention_mask = True,
    verbose = True)

# %%
input_ids = x_train['input_ids']
attention_mask = x_train['attention_mask']

# %%
x_train['input_ids']
# Out:
# <tf.Tensor: shape=(1302, 24), dtype=int32, numpy=
# array([[  101,   146,  1169, ...,     0,     0,     0],
#        [  101,  1109, 10332, ...,     0,     0,     0],
#        [  101,  1109, 10332, ...,     0,     0,     0],
#        ...,
#        [  101,  5268,  1110, ...,     0,     0,     0],
#        [  101,  8149,  1110, ...,     0,     0,     0],
#        [  101,  1302,  4778, ...,     0,     0,     0]])>

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.initializers import TruncatedNormal
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import CategoricalAccuracy
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Input, Dense

# %%
max_len = 24
input_ids = Input(shape=(max_len,), dtype=tf.int32, name="input_ids")
input_mask = Input(shape=(max_len,), dtype=tf.int32, name="attention_mask")
embeddings = bert(input_ids,attention_mask = input_mask)[0] 
out = tf.keras.layers.GlobalMaxPool1D()(embeddings)
out = Dense(128, activation='relu')(out)
out = tf.keras.layers.Dropout(0.1)(out)
out = Dense(32,activation = 'relu')(out)
y = Dense(3,activation = 'softmax')(out)
model = tf.keras.Model(inputs=[input_ids, input_mask], outputs=y)
model.layers[2].trainable = True

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_ids (InputLayer)         [(None, 24)]         0           []
#
#  attention_mask (InputLayer)    [(None, 24)]         0           []
#
#  tf_bert_model (TFBertModel)    TFBaseModelOutputWi  108310272   ['input_ids[0][0]',
#                                 thPoolingAndCrossAt               'attention_mask[0][0]']
#                                 tentions(last_hidde
#                                 n_state=(None, 24,
#                                 768),
#                                  pooler_output=(Non
#                                 e, 768),
#                                  past_key_values=No
#                                 ne, hidden_states=N
#                                 one, attentions=Non
#                                 e, cross_attentions
#                                 =None)
#
#  global_max_pooling1d (GlobalMa  (None, 768)         0           ['tf_bert_model[0][0]']
#  xPooling1D)
#
#  dense (Dense)                  (None, 128)          98432       ['global_max_pooling1d[0][0]']
#
#  dropout_37 (Dropout)           (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 32)           4128        ['dropout_37[0][0]']
#
#  dense_2 (Dense)                (None, 3)            99          ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 108,412,931
# Trainable params: 108,412,931
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
optimizer = Adam(
    learning_rate=5e-05, # this learning rate is for bert model , taken from huggingface website 
    epsilon=1e-08,
    clipnorm=1.0)
# Set loss and metrics
loss =CategoricalCrossentropy(from_logits = True)
metric = CategoricalAccuracy('balanced_accuracy'),
# Compile the model
model.compile(
    optimizer = optimizer,
    loss = loss, 
    metrics = metric)

# %%
train_history = model.fit(
    x ={'input_ids':x_train['input_ids'],'attention_mask':x_train['attention_mask']} ,y = y_train,epochs=15,batch_size=36)
# Out:
# Epoch 1/15
# C:\Users\divye\AppData\Local\Programs\Python\Python310\lib\site-packages\tensorflow\python\util\dispatch.py:1082: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   return dispatch_target(*args, **kwargs)
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# WARNING:tensorflow:Gradients do not exist for variables ['tf_bert_model/bert/pooler/dense/kernel:0', 'tf_bert_model/bert/pooler/dense/bias:0'] when minimizing the loss. If you're using `model.compile()`, did you forget to provide a `loss`argument?
# 37/37 [==============================] - 114s 3s/step - loss: 0.7860 - balanced_accuracy: 0.6575
# Epoch 2/15
# 37/37 [==============================] - 118s 3s/step - loss: 0.4108 - balanced_accuracy: 0.8656
# Epoch 3/15
# 37/37 [==============================] - 131s 4s/step - loss: 0.2993 - balanced_accuracy: 0.8978
# Epoch 4/15
# 37/37 [==============================] - 130s 4s/step - loss: 0.2040 - balanced_accuracy: 0.9370
# Epoch 5/15
# 37/37 [==============================] - 132s 4s/step - loss: 0.1678 - balanced_accuracy: 0.9432
# Epoch 6/15
# 37/37 [==============================] - 134s 4s/step - loss: 0.1460 - balanced_accuracy: 0.9478
# Epoch 7/15
# 37/37 [==============================] - 137s 4s/step - loss: 0.1266 - balanced_accuracy: 0.9547
# Epoch 8/15
# 37/37 [==============================] - 133s 4s/step - loss: 0.1172 - balanced_accuracy: 0.9647
# Epoch 9/15
# 37/37 [==============================] - 134s 4s/step - loss: 0.0859 - balanced_accuracy: 0.9685
# Epoch 10/15
# 37/37 [==============================] - 126s 3s/step - loss: 0.0799 - balanced_accuracy: 0.9708
# Epoch 11/15
# 37/37 [==============================] - 110s 3s/step - loss: 0.0674 - balanced_accuracy: 0.9754
# Epoch 12/15
# 37/37 [==============================] - 104s 3s/step - loss: 0.0696 - balanced_accuracy: 0.9708
# Epoch 13/15
# 37/37 [==============================] - 99s 3s/step - loss: 0.0658 - balanced_accuracy: 0.9685
# Epoch 14/15
# 37/37 [==============================] - 99s 3s/step - loss: 0.0793 - balanced_accuracy: 0.9700
# Epoch 15/15
# 37/37 [==============================] - 107s 3s/step - loss: 0.0602 - balanced_accuracy: 0.9739

# %%
texts = input(str('input the text:'))
x_val = tokenizer(
    text=texts,
    add_special_tokens=True,
    max_length=24,
    truncation=True,
    padding='max_length', 
    return_tensors='tf',
    return_token_type_ids = False,
    return_attention_mask = True,
    verbose = True) 
validation = model.predict({'input_ids':x_val['input_ids'],'attention_mask':x_val['attention_mask']})*100
for key , value in zip(encoded_dict.keys(),validation[0]):
    print(key,value)
# Out:
# input the text:internet connection isn't working
# Neutral 0.010059273
# Positive 0.018538713
# Negative 99.9714
